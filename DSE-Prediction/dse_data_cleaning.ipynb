# %% [markdown]
# # Dataset Cleaning for Drug-Aftereffect Prediction

# %%
import pandas as pd

# %% [markdown]
# ## Data Processing

# %%
snap_df = pd.read_csv("Dataset/ChSe-Decagon_monopharmacy.csv")
mappings_df = pd.read_csv("Dataset/drug-mappings.tsv", sep='\t')

# %%
print(snap_df.columns)
print(mappings_df.columns)
# Out:
# Index(['# STITCH', 'Individual Side Effect', 'Side Effect Name'], dtype='object')
# Index(['drugbankId', 'name', 'ttd_id', 'pubchem_cid', 'cas_num', 'chembl_id',
#        'zinc_id', 'chebi_id', 'kegg_cid', 'kegg_id', 'bindingDB_id',
#        'UMLS_cuis', 'stitch_id'],
#       dtype='object')

# %%
snap_df["# STITCH"].unique()
# Out:
# array(['CID003062316', 'CID000003117', 'CID000003114', 'CID000003730',
#        'CID000003736', 'CID000003734', 'CID000002646', 'CID000028112',
#        'CID004183806', 'CID000002462', 'CID000005381', 'CID000125889',
#        'CID000005245', 'CID000004034', 'CID000003937', 'CID005362070',
#        'CID000003121', 'CID000003382', 'CID000003381', 'CID000003386',
#        'CID000003384', 'CID000003385', 'CID000002656', 'CID000002650',
#        'CID000003706', 'CID000003702', 'CID000005978', 'CID000002471',
#        'CID000002477', 'CID000002476', 'CID000002474', 'CID000002478',
#        'CID000005394', 'CID000005391', 'CID000041693', 'CID000057537',
#        'CID000004739', 'CID000004736', 'CID000004730', 'CID000004044',
#        'CID000004046', 'CID005311297', 'CID000000815', 'CID000003394',
#        'CID000003397', 'CID000003393', 'CID000002662', 'CID000002666',
#        'CID000003249', 'CID000003715', 'CID000004943', 'CID000004946',
#        'CID000005496', 'CID000060852', 'CID000004547', 'CID000004543',
#        'CID000004542', 'CID000005234', 'CID000004727', 'CID003468412',
#        'CID005281007', 'CID000004053', 'CID000004052', 'CID000004054',
#        'CID000004058', 'CID005362420', 'CID000047320', 'CID004659569',
#        'CID004659568', 'CID000005544', 'CID000002678', 'CID000002675',
#        'CID000002676', 'CID000003278', 'CID000003279', 'CID000005005',
#        'CID000005002', 'CID000005482', 'CID000005487', 'CID000005486',
#        'CID000060754', 'CID000004536', 'CID000170361', 'CID000004064',
#        'CID000003878', 'CID000003877', 'CID000148192', 'CID000000838',
#        'CID000000298', 'CID005282044', 'CID000060696', 'CID000002609',
#        'CID000012536', 'CID000003261', 'CID000002022', 'CID000005035',
#        'CID000003516', 'CID000005038', 'CID000005039', 'CID000003510',
#        'CID000024486', 'CID000005212', 'CID000005210', 'CID000005215',
#        'CID000004075', 'CID000005593', 'CID000001134', 'CID000000191',
#        'CID000003869', 'CID000003152', 'CID000068844', 'CID000000772',
#        'CID000005206', 'CID000123631', 'CID000003075', 'CID000003696',
#        'CID000003690', 'CID000002610', 'CID000002617', 'CID000068740',
#        'CID000077992', 'CID000077993', 'CID000077999', 'CID000003488',
#        'CID000005029', 'CID000004513', 'CID000004510', 'CID000004889',
#        'CID000004885', 'CID000005203', 'CID000072467', 'CID000213039',
#        'CID000003066', 'CID000002622', 'CID000003203', 'CID000005454',
#        'CID000002487', 'CID000093860', 'CID000074989', 'CID000176870',
#        'CID000004506', 'CID000002554', 'CID000002550', 'CID000002551',
#        'CID000004894', 'CID000004893', 'CID000004095', 'CID000004091',
#        'CID000005453', 'CID000001117', 'CID004475485', 'CID000010631',
#        'CID000002727', 'CID000051634', 'CID000004211', 'CID000003059',
#        'CID000002631', 'CID000002637', 'CID000504578', 'CID000216326',
#        'CID005381226', 'CID000002019', 'CID000005040', 'CID000002541',
#        'CID000005267', 'CID000004138', 'CID000119607', 'CID000054454',
#        'CID000003255', 'CID000000564', 'CID000001302', 'CID000002658',
#        'CID000003040', 'CID000003043', 'CID000003042', 'CID000197712',
#        'CID000003222', 'CID000003559', 'CID000104865', 'CID006447131',
#        'CID000131536', 'CID000005076', 'CID000005077', 'CID000002578',
#        'CID000005073', 'CID000005070', 'CID000002576', 'CID000005078',
#        'CID000123606', 'CID000005525', 'CID000005253', 'CID000005523',
#        'CID000160051', 'CID000003823', 'CID000003821', 'CID000003827',
#        'CID000003826', 'CID000003825', 'CID000039765', 'CID000041774',
#        'CID006918453', 'CID000163742', 'CID000054841', 'CID000003032',
#        'CID000004828', 'CID000003784', 'CID000003780', 'CID000002786',
#        'CID000039860', 'CID000005064', 'CID000005538', 'CID000000444',
#        'CID000002215', 'CID000005533', 'CID000005530', 'CID000004112',
#        'CID003081884', 'CID000001546', 'CID000054786', 'CID000000942',
#        'CID000104741', 'CID000005478', 'CID000003793', 'CID000002311',
#        'CID000002771', 'CID000152945', 'CID000002512', 'CID000002519',
#        'CID000005505', 'CID000027991', 'CID000004509', 'CID000004107',
#        'CID000000206', 'CID000000937', 'CID000003016', 'CID005311082',
#        'CID000003746', 'CID000002764', 'CID000002187', 'CID000002182',
#        'CID000013342', 'CID000004473', 'CID000005515', 'CID000005514',
#        'CID000002232', 'CID000038904', 'CID000056959', 'CID000004170',
#        'CID000004171', 'CID000004173', 'CID000004178', 'CID000000214',
#        'CID000003003', 'CID000003007', 'CID000003008', 'CID000151165',
#        'CID004479097', 'CID000443871', 'CID000027661', 'CID000002756',
#        'CID000005746', 'CID000005512', 'CID000005291', 'CID000002244',
#        'CID000005297', 'CID005481350', 'CID000001206', 'CID000004168',
#        'CID000004917', 'CID000091270', 'CID000054808', 'CID000005426',
#        'CID003086258', 'CID000003291', 'CID000176168', 'CID000002749',
#        'CID000056339', 'CID003002190', 'CID000002520', 'CID000002522',
#        'CID000002524', 'CID000005572', 'CID000002250', 'CID000005578',
#        'CID000036811', 'CID000004485', 'CID000110634', 'CID000004158',
#        'CID000004159', 'CID000000271', 'CID006398970', 'CID000154059',
#        'CID000002732', 'CID000002733', 'CID000042113', 'CID000002083',
#        'CID000004599', 'CID000002088', 'CID000060147', 'CID000004497',
#        'CID000004499', 'CID000004812', 'CID000002269', 'CID000002266',
#        'CID000002267', 'CID000002265', 'CID000004819', 'CID000004140',
#        'CID000004635', 'CID000004634', 'CID000001046', 'CID000060953',
#        'CID000000581', 'CID000060795', 'CID000002891', 'CID000002720',
#        'CID000002895', 'CID000002726', 'CID000002725', 'CID000145068',
#        'CID000003637', 'CID000003639', 'CID000003419', 'CID000003410',
#        'CID000003414', 'CID000002092', 'CID000002099', 'CID000003062',
#        'CID000005771', 'CID000005155', 'CID000005152', 'CID000004829',
#        'CID000002274', 'CID000005556', 'CID000004609', 'CID000004603',
#        'CID000004601', 'CID000004607', 'CID000001071', 'CID003085017',
#        'CID006436173', 'CID005281104', 'CID001349907', 'CID005329102',
#        'CID000060787', 'CID000002712', 'CID000002713', 'CID000002719',
#        'CID000003405', 'CID000003404', 'CID000003403', 'CID000060164',
#        'CID000004834', 'CID000002284', 'CID000002283', 'CID000004614',
#        'CID000004616', 'CID000001065', 'CID000062924', 'CID000130881',
#        'CID005493444', 'CID000115237', 'CID000003658', 'CID000002708',
#        'CID000003652', 'CID000003657', 'CID000060198', 'CID000005719',
#        'CID000005717', 'CID000004999', 'CID000004440', 'CID000004993',
#        'CID000004991', 'CID000004449', 'CID005311027', 'CID000004845',
#        'CID000004192', 'CID000004666', 'CID000004195', 'CID000003899',
#        'CID000008953', 'CID000041781', 'CID000004264', 'CID009571074',
#        'CID005311039', 'CID000002909', 'CID000002907', 'CID000027686',
#        'CID000003648', 'CID000003642', 'CID000003463', 'CID000003461',
#        'CID000003467', 'CID000002249', 'CID000124087', 'CID000005726',
#        'CID000005721', 'CID000002118', 'CID000004451', 'CID000004856',
#        'CID000005584', 'CID000003883', 'CID000004675', 'CID000004674',
#        'CID000004679', 'CID000048175', 'CID000041317', 'CID000004189',
#        'CID000071329', 'CID000003676', 'CID000003675', 'CID000003672',
#        'CID000003476', 'CID000003478', 'CID000002585', 'CID000034312',
#        'CID000005731', 'CID000005732', 'CID000005735', 'CID000005734',
#        'CID000003324', 'CID000003325', 'CID000003454', 'CID006435110',
#        'CID000004463', 'CID000005596', 'CID000444013', 'CID000004645',
#        'CID000001690', 'CID005473385', 'CID000003198', 'CID000003661',
#        'CID000150610', 'CID000003449', 'CID000002130', 'CID000003339',
#        'CID000003440', 'CID000003333', 'CID000003446', 'CID000005472',
#        'CID000004873', 'CID000005878', 'CID000004253', 'CID000004259',
#        'CID000001972', 'CID000001971', 'CID000060865', 'CID000001978',
#        'CID000000085', 'CID000004539', 'CID000087177', 'CID000040976',
#        'CID000002951', 'CID000002955', 'CID000000158', 'CID000000159',
#        'CID000003890', 'CID005487301', 'CID000147912', 'CID000024011',
#        'CID000003308', 'CID000003305', 'CID000005466', 'CID000002308',
#        'CID000004409', 'CID000125017', 'CID000054688', 'CID000072938',
#        'CID000444033', 'CID000003310', 'CID000060877', 'CID000060871',
#        'CID000019090', 'CID000002949', 'CID000000143', 'CID000071158',
#        'CID000002806', 'CID000002802', 'CID000002803', 'CID000002800',
#        'CID000002801', 'CID000016231', 'CID000051263', 'CID000005672',
#        'CID000002153', 'CID000002156', 'CID000002370', 'CID000005412',
#        'CID000002375', 'CID005353980', 'CID000072054', 'CID000005095',
#        'CID000005090', 'CID000064147', 'CID000004419', 'CID000004411',
#        'CID000004236', 'CID000001775', 'CID000156419', 'CID000060843',
#        'CID005311048', 'CID000003958', 'CID000003957', 'CID000003954',
#        'CID000014888', 'CID000002978', 'CID000002973', 'CID000002812',
#        'CID000002818', 'CID000216239', 'CID000003143', 'CID000003148',
#        'CID000003767', 'CID000003763', 'CID000002142', 'CID000002141',
#        'CID000003365', 'CID000003494', 'CID000003367', 'CID000005402',
#        'CID000005401', 'CID000002369', 'CID000005408', 'CID000004425',
#        'CID000004932', 'CID000004428', 'CID000004205', 'CID000004200',
#        'CID000004201', 'CID000060854', 'CID000003962', 'CID000003961',
#        'CID000003964', 'CID000054547', 'CID005311181', 'CID000036339',
#        'CID000003157', 'CID000003154', 'CID000122316', 'CID000003158',
#        'CID000005650', 'CID000005651', 'CID000005656', 'CID000047725',
#        'CID000002177', 'CID000002173', 'CID000002170', 'CID000002171',
#        'CID000003373', 'CID000003372', 'CID000003379', 'CID000006691',
#        'CID000657298', 'CID000060612', 'CID000150310', 'CID000150311',
#        'CID000004927', 'CID000004920', 'CID000004748', 'CID000004745',
#        'CID000004212', 'CID000004740', 'CID005493381', 'CID000004691',
#        'CID000003640', 'CID006398525', 'CID000000598', 'CID000000596',
#        'CID000002995', 'CID000148211', 'CID000000119', 'CID000508230',
#        'CID000071616', 'CID000119182', 'CID000110635', 'CID000667490',
#        'CID000003161', 'CID000003168', 'CID000003749', 'CID000003741',
#        'CID000002160', 'CID000002162', 'CID000003348', 'CID000003345',
#        'CID000065999', 'CID000005645', 'CID000005647', 'CID000004594',
#        'CID000004595', 'CID000002349', 'CID000004913', 'CID000004911',
#        'CID000082146', 'CID000002435', 'CID000004771', 'CID000005352',
#        'CID000005358', 'CID000057469', 'CID000060831', 'CID000060835',
#        'CID000003902', 'CID000060184', 'CID000000853', 'CID000009433',
#        'CID000000453', 'CID000000450', 'CID000001983', 'CID000001986',
#        'CID000153941', 'CID000003750', 'CID000012620', 'CID000003350',
#        'CID000003355', 'CID000004583', 'CID000004585', 'CID000004909',
#        'CID000004900', 'CID000005184', 'CID000002405', 'CID000009052',
#        'CID000004011', 'CID000003911', 'CID000003914', 'CID000000861',
#        'CID000059708', 'CID000071273', 'CID000003108', 'CID000003724',
#        'CID000083786', 'CID000065027', 'CID000060815', 'CID000054374',
#        'CID000005195', 'CID000005379', 'CID000005372', 'CID000005376',
#        'CID000003929', 'CID000032797', 'CID005282226'], dtype=object)

# %%
# For each STITCH # in snap_df, use mappings_df to find the corresponding drugbankId and name

stitches = snap_df["# STITCH"].unique()
results = []
not_found = []

for stitch in stitches:
    mapping = mappings_df[mappings_df["stitch_id"] == stitch]
    if not mapping.empty:
        drugbankId = mapping["drugbankId"].values[0]
        name = mapping["name"].values[0]
        results.append((stitch, drugbankId, name))
    else:
        not_found.append(stitch)

# %%
print(len(results))
print(len(not_found))
# Out:
# 321
# 318

# %%
not_found
# Out:
# ['CID000003734',
#  'CID000002646',
#  'CID000028112',
#  'CID004183806',
#  'CID000002462',
#  'CID000125889',
#  'CID000003937',
#  'CID005362070',
#  'CID000003382',
#  'CID000003381',
#  'CID000003384',
#  'CID000002656',
#  'CID000002650',
#  'CID000003706',
#  'CID000002476',
#  'CID000057537',
#  'CID000004739',
#  'CID000004736',
#  'CID000004730',
#  'CID000004046',
#  'CID005311297',
#  'CID000000815',
#  'CID000002666',
#  'CID000003249',
#  'CID000005496',
#  'CID000004547',
#  'CID000004542',
#  'CID000005234',
#  'CID000004727',
#  'CID003468412',
#  'CID005281007',
#  'CID000004053',
#  'CID000004052',
#  'CID004659568',
#  'CID000005544',
#  'CID000002675',
#  'CID000002676',
#  'CID000003279',
#  'CID000005005',
#  'CID000005482',
#  'CID000005486',
#  'CID000060754',
#  'CID000004536',
#  'CID000170361',
#  'CID000003877',
#  'CID000000838',
#  'CID000000298',
#  'CID005282044',
#  'CID000060696',
#  'CID000002609',
#  'CID000012536',
#  'CID000005038',
#  'CID000005039',
#  'CID000003510',
#  'CID000024486',
#  'CID000001134',
#  'CID000000191',
#  'CID000000772',
#  'CID000003075',
#  'CID000002610',
#  'CID000002617',
#  'CID000077999',
#  'CID000004513',
#  'CID000004889',
#  'CID000004885',
#  'CID000005203',
#  'CID000072467',
#  'CID000003066',
#  'CID000002622',
#  'CID000003203',
#  'CID000005454',
#  'CID000002487',
#  'CID000093860',
#  'CID000002550',
#  'CID000002551',
#  'CID000004894',
#  'CID000001117',
#  'CID004475485',
#  'CID000010631',
#  'CID000002631',
#  'CID000002637',
#  'CID000504578',
#  'CID000002019',
#  'CID000005040',
#  'CID000005267',
#  'CID000004138',
#  'CID000003255',
#  'CID000001302',
#  'CID000002658',
#  'CID000003040',
#  'CID000003043',
#  'CID000197712',
#  'CID000003222',
#  'CID006447131',
#  'CID000131536',
#  'CID000005076',
#  'CID000005077',
#  'CID000005525',
#  'CID000005523',
#  'CID000160051',
#  'CID000003823',
#  'CID000039765',
#  'CID000041774',
#  'CID006918453',
#  'CID000163742',
#  'CID000054841',
#  'CID000003032',
#  'CID000003780',
#  'CID000002786',
#  'CID000039860',
#  'CID000005064',
#  'CID000005538',
#  'CID000002215',
#  'CID000004112',
#  'CID003081884',
#  'CID000001546',
#  'CID000054786',
#  'CID000000942',
#  'CID000104741',
#  'CID000005478',
#  'CID000003793',
#  'CID000002311',
#  'CID000152945',
#  'CID000002512',
#  'CID000027991',
#  'CID000004509',
#  'CID000000206',
#  'CID000000937',
#  'CID005311082',
#  'CID000003746',
#  'CID000004473',
#  'CID000005515',
#  'CID000005514',
#  'CID000002232',
#  'CID000000214',
#  'CID000003003',
#  'CID000003008',
#  'CID000151165',
#  'CID004479097',
#  'CID000443871',
#  'CID000005512',
#  'CID000005297',
#  'CID000001206',
#  'CID000091270',
#  'CID000054808',
#  'CID003086258',
#  'CID000176168',
#  'CID000056339',
#  'CID000002522',
#  'CID000002524',
#  'CID000002250',
#  'CID000004159',
#  'CID000000271',
#  'CID006398970',
#  'CID000154059',
#  'CID000004599',
#  'CID000060147',
#  'CID000004812',
#  'CID000002269',
#  'CID000004819',
#  'CID000004140',
#  'CID000004635',
#  'CID000000581',
#  'CID000002891',
#  'CID000003419',
#  'CID000003414',
#  'CID000003062',
#  'CID000005771',
#  'CID000005155',
#  'CID000002274',
#  'CID000004609',
#  'CID000004603',
#  'CID000004607',
#  'CID000001071',
#  'CID000060787',
#  'CID000002713',
#  'CID000003405',
#  'CID000003404',
#  'CID000003403',
#  'CID000004834',
#  'CID000002283',
#  'CID000001065',
#  'CID000062924',
#  'CID000130881',
#  'CID000004666',
#  'CID000008953',
#  'CID000004264',
#  'CID009571074',
#  'CID005311039',
#  'CID000002909',
#  'CID000027686',
#  'CID000003648',
#  'CID000003642',
#  'CID000003461',
#  'CID000005726',
#  'CID000005721',
#  'CID000004451',
#  'CID000004856',
#  'CID000004675',
#  'CID000004674',
#  'CID000048175',
#  'CID000041317',
#  'CID000005731',
#  'CID000003325',
#  'CID006435110',
#  'CID000005596',
#  'CID000004645',
#  'CID000001690',
#  'CID005473385',
#  'CID000003661',
#  'CID000003449',
#  'CID000004873',
#  'CID000004253',
#  'CID000004259',
#  'CID000001972',
#  'CID000001971',
#  'CID000060865',
#  'CID000000085',
#  'CID000087177',
#  'CID000040976',
#  'CID000002951',
#  'CID000000158',
#  'CID000000159',
#  'CID000003890',
#  'CID005487301',
#  'CID000147912',
#  'CID000024011',
#  'CID000005466',
#  'CID000002308',
#  'CID000054688',
#  'CID000072938',
#  'CID000444033',
#  'CID000003310',
#  'CID000019090',
#  'CID000002949',
#  'CID000000143',
#  'CID000002806',
#  'CID000002800',
#  'CID000016231',
#  'CID000005672',
#  'CID000002156',
#  'CID000005412',
#  'CID005353980',
#  'CID000072054',
#  'CID000004419',
#  'CID000004411',
#  'CID000156419',
#  'CID000060843',
#  'CID005311048',
#  'CID000003954',
#  'CID000014888',
#  'CID000002978',
#  'CID000003143',
#  'CID000003148',
#  'CID000002142',
#  'CID000003494',
#  'CID000003367',
#  'CID000005402',
#  'CID000005408',
#  'CID000004425',
#  'CID000004428',
#  'CID000004200',
#  'CID000060854',
#  'CID000003962',
#  'CID000054547',
#  'CID000036339',
#  'CID000003154',
#  'CID000122316',
#  'CID000003158',
#  'CID000005650',
#  'CID000005651',
#  'CID000047725',
#  'CID000002177',
#  'CID000002173',
#  'CID000002171',
#  'CID000003379',
#  'CID000006691',
#  'CID000060612',
#  'CID000150310',
#  'CID000004920',
#  'CID000004745',
#  'CID000004691',
#  'CID000003640',
#  'CID006398525',
#  'CID000000596',
#  'CID000148211',
#  'CID000508230',
#  'CID000003161',
#  'CID000005645',
#  'CID000005647',
#  'CID000002349',
#  'CID000005352',
#  'CID000060831',
#  'CID000060835',
#  'CID000060184',
#  'CID000000853',
#  'CID000000453',
#  'CID000000450',
#  'CID000003750',
#  'CID000003350',
#  'CID000003355',
#  'CID000004900',
#  'CID000005184',
#  'CID000009052',
#  'CID000003911',
#  'CID000003914',
#  'CID000000861',
#  'CID000059708',
#  'CID000071273',
#  'CID000083786',
#  'CID000065027',
#  'CID000060815',
#  'CID000054374',
#  'CID000005195',
#  'CID000005372',
#  'CID000005376',
#  'CID000003929',
#  'CID000032797']

# %%
dn = pd.read_csv("Dataset/drug_names.csv", header=None)

# %%
dnl = list(dn[0])

# %%
still_nf = []
for name in not_found:
    if name not in dnl:
        still_nf.append(name)

# %%
mydf = pd.DataFrame(not_found, columns=["stitch"])

# %%
test_list = []
for name in stitches:
    if name not in dnl:
        test_list.append(name)

# %%
for name in dnl:
    if name not in stitches:
        print(name)
# Out:
# CID000002673
# CID000003562
# CID000003928
# CID000004723
# CID000005052
# CID000123620

# %% [markdown]
# **ALL THE STITCHES ARE IN THE drug_names.csv FILE AND HAVE CORRESPONDING NAMES**

# %% [markdown]
# See if all of these names exist in the drug-mappings.tsv file

# %%
all_names = list(dn[1])

# %%
mapNames = mappings_df["name"].unique()

# %%
missing = []
for name in all_names:
    if name not in mapNames:
        missing.append(name)

# %%
all_names
# Out:
# ['carnitine',
#  'GABA',
#  'leucovorin',
#  'PGE2',
#  'prostacyclin',
#  'adenosine',
#  'galactose',
#  'prostaglandin E1',
#  'calcium',
#  'chloramphenicol',
#  'bupropion',
#  'estradiol',
#  'mannitol',
#  'epsilon-aminocaproic acid',
#  'N-acetylcysteine',
#  'cytosine arabinoside',
#  'mesna',
#  'heparin',
#  'kanamycin',
#  'epinephrine',
#  'thyroxine',
#  'triiodothyronine',
#  'nicotinic acid',
#  'nicotine',
#  'pyrazinamide',
#  'quinidine',
#  'vitamin A',
#  'sulfate',
#  'thymidine',
#  'methamphetamine',
#  'naproxen',
#  '2-chlorodeoxyadenosine',
#  'doxorubicin',
#  'phenytoin',
#  'abacavir',
#  'amphotericin B',
#  'acebutolol',
#  'acetaminophen',
#  'acetazolamide',
#  'actinomycin D',
#  'acyclovir',
#  'salbutamol',
#  'alendronate',
#  'alfuzosin',
#  'alosetron',
#  'alprazolam',
#  'amantadine',
#  'amifostine',
#  'amikacin',
#  'theophylline',
#  'amiodarone',
#  'amitriptyline',
#  'amlodipine',
#  'amoxapine',
#  'amoxicillin',
#  'ampicillin',
#  'amprenavir',
#  'anagrelide',
#  'anastrozole',
#  'apomorphine',
#  'argatroban',
#  'aspirin',
#  'atenolol',
#  'atorvastatin',
#  'azathioprine',
#  'azelaic acid',
#  'azelastine',
#  'azithromycin',
#  'aztreonam',
#  'bacitracin',
#  'baclofen',
#  'beclomethasone',
#  'benazepril',
#  'penicillin G',
#  'betaxolol',
#  'bethanechol',
#  'bicalutamide',
#  'bisoprolol',
#  'brimonidine',
#  'budesonide',
#  'bumetanide',
#  'bupivacaine',
#  'buprenorphine',
#  'buspirone',
#  'busulfan',
#  'butorphanol',
#  'cabergoline',
#  'caffeine',
#  'verapamil',
#  'calcipotriol',
#  'calcitriol',
#  'candesartan',
#  'captopril',
#  'carbachol',
#  'carbamazepine',
#  'carisoprodol',
#  'BCNU',
#  'carvedilol',
#  'cefaclor',
#  'cefadroxil',
#  'cefazolin',
#  'cefepime',
#  'cefotaxime',
#  'cefoxitin',
#  'cefprozil',
#  'ceftazidime',
#  'ceftriaxone',
#  'cefuroxime',
#  'celecoxib',
#  'cephalexin',
#  'cephradine',
#  'cefixime',
#  'cerivastatin',
#  'cetirizine',
#  'chlorambucil',
#  'chlordiazepoxide',
#  'chlorhexidine',
#  'chloroquine',
#  'chlorothiazide',
#  'chlorpheniramine',
#  'chlorpromazine',
#  'chlorpropamide',
#  'chlorthalidone',
#  'chlorzoxazone',
#  'ciclopirox',
#  'cimetidine',
#  'ciprofloxacin',
#  'citalopram',
#  'clindamycin',
#  'clomiphene citrate',
#  'clomipramine',
#  'clonazepam',
#  'clonidine',
#  'clopidogrel',
#  'clotrimazole',
#  'clozapine',
#  'vitamin B12',
#  'cyclobenzaprine',
#  'cyclophosphamide',
#  'cyclosporine',
#  'danazol',
#  'dantrolene',
#  'dapsone',
#  'desferrioxamine',
#  'delta 9-tetrahydrocannabinol',
#  'desipramine',
#  'dexamethasone',
#  'amphetamine',
#  'dextromethorphan',
#  'diazepam',
#  'diclofenac',
#  'dicloxacillin',
#  'dicyclomine',
#  'didanosine',
#  'diflunisal',
#  'digoxin',
#  'dihydroergotamine',
#  'diltiazem',
#  'dipyridamole',
#  'disopyramide',
#  'disulfiram',
#  'valproic acid',
#  'docetaxel',
#  'dolasetron',
#  'donepezil',
#  'Ets',
#  'doxazosin',
#  'doxepin',
#  'doxycycline',
#  'droperidol',
#  'econazole',
#  'efavirenz',
#  'enalapril',
#  'vitamin D',
#  'erythromycin',
#  'estazolam',
#  'ethacrynic acid',
#  'ethambutol',
#  'ethosuximide',
#  'EHDP',
#  'etodolac',
#  'etoposide',
#  'famciclovir',
#  'famotidine',
#  'felodipine',
#  'fenofibrate',
#  'fentanyl',
#  'fexofenadine',
#  'finasteride',
#  'flecainide',
#  'fluconazole',
#  'fludarabine',
#  'fluphenazine',
#  'flumazenil',
#  'flunisolide',
#  'fluocinolone acetonide',
#  'fluocinonide',
#  'fluorometholone',
#  '5-fluorouracil',
#  'fluoxetine',
#  'flurazepam',
#  'flurbiprofen',
#  'flutamide',
#  'fluvastatin',
#  'fluvoxamine',
#  'folate',
#  'formoterol',
#  'foscarnet',
#  'fosinopril',
#  'furosemide',
#  'gabapentin',
#  'galantamine',
#  'ganciclovir',
#  'gemcitabine',
#  'gemfibrozil',
#  'gentamicin',
#  'glimepiride',
#  'glipizide',
#  'glibenclamide',
#  'glycopyrrolate',
#  'granisetron',
#  'GGG',
#  'haloperidol',
#  'halothane',
#  'hydralazine',
#  'hydrochlorothiazide',
#  'cortisol',
#  'hydrocortisone butyrate',
#  'hydromorphone',
#  'hydroxychloroquine',
#  'hydroxyurea',
#  'hydroxyzine',
#  'atropine',
#  'ibuprofen',
#  'phenelzine',
#  'lidocaine',
#  'ifosfamide',
#  'imipramine',
#  'indapamide',
#  'indinavir',
#  'indomethacin',
#  'iodixanol',
#  'iohexol',
#  'iopamidol',
#  'iopromide',
#  'ioversol',
#  'ipratropium bromide',
#  'irbesartan',
#  'irinotecan',
#  'isoflurane',
#  'isoniazid',
#  'isosorbide dinitrate',
#  'isradipine',
#  'itraconazole',
#  'ketamine',
#  'ketoconazole',
#  'ketoprofen',
#  'ketorolac',
#  'ketotifen',
#  'labetalol',
#  'lamivudine',
#  'lamotrigine',
#  'lansoprazole',
#  'latanoprost',
#  'leflunomide',
#  'letrozole',
#  'leuprolide acetate',
#  'levobunolol',
#  'lincomycin',
#  'linezolid',
#  'lisinopril',
#  'loperamide',
#  'loratadine',
#  'lorazepam',
#  'losartan',
#  'lovastatin',
#  'loxapine',
#  'maprotiline',
#  'monamine',
#  'mefenamic acid',
#  'mefloquine',
#  'meloxicam',
#  'melphalan',
#  'memantine',
#  'meperidine',
#  'meprobamate',
#  '5-aminosalicylic acid',
#  'metformin',
#  'methadone',
#  'methocarbamol',
#  'methotrexate',
#  'methyldopa',
#  'methylergometrine',
#  'methylphenidate',
#  'methylprednisolone',
#  'metoclopramide',
#  'metolazone',
#  'metoprolol',
#  'metronidazole',
#  'mexiletine',
#  'miconazole',
#  'midazolam',
#  'midodrine',
#  'minocycline',
#  'minoxidil',
#  'mirtazapine',
#  'mitotane',
#  'mitoxantrone',
#  'modafinil',
#  'morphine',
#  'moxifloxacin',
#  'mupirocin',
#  'nabumetone',
#  'nadolol',
#  'nalbuphine',
#  'naloxone',
#  'naltrexone',
#  'naratriptan',
#  'nefazodone',
#  'nelfinavir',
#  'nevirapine',
#  'nicardipine',
#  'nifedipine',
#  'nimodipine',
#  'nisoldipine',
#  'nitrazepam',
#  'nitrofurantoin',
#  'nitroglycerin',
#  'nizatidine',
#  'norethisterone',
#  'norfloxacin',
#  'levonorgestrel',
#  'nortriptyline',
#  'repaglinide',
#  'ofloxacin',
#  'olanzapine',
#  'omeprazole',
#  'ondansetron',
#  'orlistat',
#  'orphenadrine',
#  'oseltamivir',
#  'oxacillin',
#  'oxaliplatin',
#  'oxaprozin',
#  'oxazepam',
#  'oxybutynin',
#  'oxycodone',
#  'oxytetracycline',
#  'paclitaxel',
#  'pamidronate',
#  'pancuronium',
#  'pantoprazole',
#  'paroxetine',
#  'pemoline',
#  'D-penicillamine',
#  'penicillin V',
#  'pentazocine',
#  'DCF',
#  'pentoxifylline',
#  'pergolide',
#  'perphenazine',
#  'phentermine',
#  'vitamin K1',
#  'pilocarpine',
#  'pindolol',
#  'pioglitazone',
#  'piperacillin',
#  'pirbuterol',
#  'piroxicam',
#  'KCl',
#  'pramipexole',
#  'pravastatin',
#  'prazosin',
#  'prednisolone',
#  'prednisone',
#  'primidone',
#  'probenecid',
#  'procainamide',
#  'prochlorperazine',
#  'progesterone',
#  'promethazine',
#  'propafenone',
#  'propofol',
#  'propranolol',
#  'pyridostigmine',
#  'pyrimethamine',
#  'quazepam',
#  'quetiapine',
#  'quinapril',
#  'rabeprazole',
#  'raloxifene',
#  'ramipril',
#  'ranitidine',
#  'rapamycin',
#  'reserpine',
#  'ribavirin',
#  'riluzole',
#  'risperidone',
#  'ritonavir',
#  'rivastigmine',
#  'rizatriptan',
#  'rofecoxib',
#  'ropinirole',
#  'salmeterol',
#  'stavudine',
#  'scopolamine',
#  'selegiline',
#  'sertraline',
#  'sevoflurane',
#  'sibutramine',
#  'sildenafil',
#  'sulfadiazine',
#  'NaCl',
#  'risedronate',
#  'sotalol',
#  'spironolactone',
#  'imatinib',
#  'streptomycin',
#  'sulindac',
#  'sumatriptan',
#  'tacrolimus',
#  'tamoxifen',
#  'gatifloxacin',
#  'tazarotene',
#  'temazepam',
#  'temozolomide',
#  'terazosin',
#  'terbinafine',
#  'testosterone',
#  'tetracycline',
#  'thalidomide',
#  'thiotepa',
#  'thiothixene',
#  'tiagabine',
#  'ticlopidine',
#  'timolol',
#  'tioconazole',
#  'tirofiban',
#  'tizanidine',
#  'tobramycin',
#  'tolbutamide',
#  'tolterodine',
#  'topiramate',
#  'topotecan',
#  'tramadol',
#  'trandolapril',
#  'tranylcypromine',
#  'trazodone',
#  'retinoic acid',
#  'triamcinolone',
#  'triazolam',
#  'trihexyphenidyl',
#  'trimethoprim',
#  'trimipramine',
#  'tropicamide',
#  'trospium chloride',
#  'ursodeoxycholic acid',
#  'valacyclovir',
#  'valsartan',
#  'vancomycin',
#  'venlafaxine',
#  'vinorelbine',
#  'zafirlukast',
#  'zaleplon',
#  'zanamivir',
#  'zidovudine',
#  'zolmitriptan',
#  'zolpidem',
#  'zonisamide',
#  'zopiclone',
#  'mitomycin C',
#  'synthetic oxytocin',
#  'oxandrolone',
#  'vincristine',
#  'warfarin',
#  'sodium bicarbonate',
#  'acenocoumarol',
#  'aminophylline',
#  'medroxyprogesterone',
#  'apolar',
#  'Tadenan',
#  'vinblastine',
#  'arsenic trioxide',
#  'amiloride',
#  'megestrol',
#  'selenium sulfide',
#  'calcium chloride',
#  'isosorbide-5-mononitrate',
#  'cromolyn',
#  'DDAVP',
#  'lithium',
#  'clobetasol',
#  'oxcarbazepine',
#  'etomidate',
#  'dobutamine',
#  'carboplatin',
#  'vecuronium',
#  'nabilone',
#  'Implanon',
#  'acitretin',
#  'sufentanil',
#  'acarbose',
#  'torasemide',
#  'desflurane',
#  'cisatracurium',
#  'goserelin',
#  'halobetasol propionate',
#  'alfentanil',
#  'N-butyldeoxynojirimycin',
#  'octreotide',
#  'simvastatin',
#  'cefpodoxime',
#  'clarithromycin',
#  'treprostinil',
#  'loteprednol etabonate',
#  'atomoxetine',
#  'fosphenytoin',
#  'ranolazine',
#  'imiquimod',
#  'N-0437',
#  'levetiracetam',
#  'tamsulosin',
#  'adapalene',
#  'perindopril',
#  'exemestane',
#  'dexmedetomidine',
#  'rocuronium',
#  'gadodiamide',
#  'saquinavir',
#  'aripiprazole',
#  'remifentanil',
#  'tiotropium',
#  'duloxetine',
#  'pemetrexed',
#  'ibandronate',
#  'ziprasidone',
#  'olopatadine',
#  'adefovir dipivoxil',
#  'FTC',
#  'capecitabine',
#  'fluticasone',
#  'valganciclovir',
#  'tipranavir',
#  'telmisartan',
#  'zoledronic acid',
#  'brinzolamide',
#  'acamprosate',
#  'ropivacaine',
#  'dofetilide',
#  'voriconazole',
#  'darifenacin',
#  'bleomycin',
#  'gemifloxacin',
#  'atovaquone',
#  'frovatriptan',
#  'eletriptan',
#  'rosiglitazone',
#  'bexarotene',
#  'allopurinol',
#  'lactulose',
#  'moexipril',
#  'bortezomib',
#  'fulvestrant',
#  'bosentan',
#  'vardenafil',
#  'tadalafil',
#  '9-hydroxyrisperidone',
#  'clofarabine',
#  'valdecoxib',
#  'RSA',
#  'almotriptan',
#  'mometasone',
#  'gefitinib',
#  'desloratadine',
#  'O-desmethylvenlafaxine',
#  'pregabalin',
#  'olmesartan medoxomil',
#  'fosamprenavir',
#  'nitric oxide',
#  'posaconazole',
#  'atazanavir',
#  'palonosetron',
#  'eplerenone',
#  'ezetimibe',
#  'ertapenem',
#  'aprepitant',
#  'dutasteride',
#  'ETV',
#  'solifenacin succinate',
#  'cinacalcet',
#  'colesevelam hydrochloride',
#  'fondaparinux sodium',
#  'varenicline',
#  'Lambda',
#  'erlotinib',
#  'ambrisentan',
#  'TMC114',
#  'sorafenib',
#  'lenalidomide',
#  'nateglinide',
#  'gadoversetamide',
#  'ciclesonide',
#  'neomycin',
#  'mycophenolic acid',
#  'propylthiouracil',
#  'mercaptopurine',
#  'methimazole',
#  'telithromycin',
#  'dasatinib',
#  'glatiramer acetate',
#  'sevelamer',
#  'porfimer sodium',
#  'nystatin',
#  'misoprostol',
#  'rosuvastatin',
#  'hydroxocobalamin',
#  'entacapone',
#  'tolcapone',
#  'dacarbazine',
#  'paricalcitol',
#  'tigecycline',
#  'travoprost',
#  'bimatoprost',
#  'caspofungin',
#  'cisplatin',
#  'eptifibatide',
#  'iloprost',
#  'montelukast',
#  'SU11248',
#  'sulfasalazine',
#  'balsalazide',
#  'verteporfin',
#  'rifampicin',
#  '6-thioguanine',
#  'tenofovir disoproxil fumarate',
#  'tegaserod',
#  'ICL670',
#  'aliskiren',
#  'sucralfate',
#  'cefdinir',
#  'ivermectin',
#  'rifaximin',
#  'pimecrolimus',
#  'auranofin',
#  'cefditoren']

# %%
sim = pd.read_csv("Dataset/drug-similarities-raw.txt", sep='\t', header=None)

# %%
sim_names = set(list(sim[0]))

# %%
found_df = pd.DataFrame(results, columns=["STITCH #", "DrugID", "Name"])

# %%
found_names = list(found_df["Name"])

# %%
sim = pd.read_csv("Dataset/drug-similarities-raw.txt", sep='\t', header=None)
sim_names = set(list(sim[0]))

# %%
print(found_df.shape)
found_df.head(15)
# Out:
# (290, 3)
#         STITCH #   DrugID          Name
# 0   CID003062316  DB01254     Dasatinib
# 1   CID000003117  DB00822    Disulfiram
# 2   CID000003114  DB00280  Disopyramide
# 3   CID000003730  DB01362       Iohexol
# 4   CID000005381  DB00799    Tazarotene
# 5   CID000004034  DB00737     Meclizine
# 6   CID000003386  DB00472    Fluoxetine
# 7   CID000003385  DB00544  Fluorouracil
# 8   CID000003702  DB00808    Indapamide
# 9   CID000005978  DB00541   Vincristine
# 10  CID000002471  DB00887    Bumetanide
# 11  CID000002477  DB00490     Buspirone
# 12  CID000002474  DB00297   Bupivacaine
# 13  CID000002478  DB01008      Busulfan
# 14  CID000005394  DB00853  Temozolomide

# %%
found_names = found_df["Name"].unique()

# Create a boolean mask for rows where both columns match the values in 'found_stitches' and 'found_names'
mask = sim[0].isin(found_names) & sim[1].isin(found_names)
snap_similarities = sim[mask].reset_index(drop=True)

# Create a dictionary from the 'found_df' DataFrame
name_to_stitch = found_df.set_index('Name')['STITCH #'].to_dict()

# Replace the names in the 'snap_similarities' DataFrame using the dictionary
snap_similarities[0] = snap_similarities[0].map(name_to_stitch)
snap_similarities[1] = snap_similarities[1].map(name_to_stitch)

# %%
snap_similarities
# Out:
#                   0             1         2
# 0      CID000071158  CID000001978  0.507569
# 1      CID000071158  CID000001983  0.517090
# 2      CID000071158  CID000001986  0.447357
# 3      CID000071158  CID000060164  0.299784
# 4      CID000071158  CID000051263  0.409945
# ...             ...           ...       ...
# 41900  CID000005719  CID000005734  0.592338
# 41901  CID000005719  CID000005735  0.729570
# 41902  CID000005732  CID000005734  0.637753
# 41903  CID000005732  CID000005735  0.837077
# 41904  CID000005734  CID000005735  0.648843
#
# [41905 rows x 3 columns]

# %% [markdown]
# ## Final Datasets:

# %%
# Drug-Aftereffect Relation Dataset
snap_df.to_csv('Dataset/Cleaned_Datasets/snap_dse.csv', index=False)

# Drug-Drug Similarity Dataset
snap_similarities.to_csv('Dataset/Cleaned_Datasets/snap_similarities.csv', index=False)
